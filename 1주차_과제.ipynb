# %% [markdown]
# <a href="https://colab.research.google.com/github/cha-jooyoung/cha-jooyoung.github.io/blob/master/1%EC%A3%BC%EC%B0%A8_%EA%B3%BC%EC%A0%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1주차 과제 (인공지능을 사용한 서비스 및 제품)**
#
# 1.   **언어**
#
# 구글 번역
#
# 2007년 구글에서 발표한 무료 번역 서비스로, 현재 세계에서 가장 많이 사용되는 기계번역 서비스이다. 구글 번역의 특성상 시간이 갈수록 정보가 많아지면서 정확도가 높아져가고 있다. 하지만 지금도 엉터리 번역이 많으니 주의해야 한다.
#
# '구글 번역기(Translator)'가 아니라 '구글 번역(Translate)'이 올바른 명칭이다. 약 200억 개의 번역된 단어를 사용하며, 번역된 단어가 없으면 소리가 나는대로 표기하고 있다. 또한 텍스트 뿐만 아니라 웹 페이지 등의 번역도 가능하다.
#
# 동사의 웹 브라우저인 크롬에서는 해당 기능이 기본적으로 내장되어서 사용자의 크롬 언어와 다른 언어로 구성된 사이트를 열면 자동으로 번역하겠느냐고 물어본다.[1] 크롬의 모바일 버전에도 있다. 번역할 수 있는 페이지는 줄바꿈(<br> 등)은 페이지 단위로 끊어진다. 하지만 그게 없다면 처음부터 끝까지 통번역을 한다. 다른 웹 브라우저에서도 확장 기능으로 구글 번역을 제공하고 있어서 크롬과 비슷하게 쓸 수는 있다. 다른 회사의 모바일 브라우저인 돌핀 브라우저에도 확장 기능으로 있을 정도다. https://namu.wiki/w/%EA%B5%AC%EA%B8%80%20%EB%B2%88%EC%97%AD#s-5
#
# 2016년에 개발된 네이버의 파파고 어플에 비해 10년 앞서있다. 처음과 비교하여 놀라운 수준의 발전을 보여주고 있으며 바이두 백과와 같은 방식으로 사용자의 의견을 수용하여 번역에 반영하는 방식으로 계속하여 품질이 상향되고 있다. 언어학적 원리에 기반한 것이 아닌 인터넷에 있는 번역정보들을 기반으로 함으로 특별히 번역 부분만이 아니더라도 다른 분야의 인공지능에도 통용될 수 있는 수단으로 보인다. 의외로 언어와는 관련이 멀다고 볼수도 있다.
#
#
# 2.   **음성**
#
# 유튜브 자동자막 서비스
#
# 유튜브는 현대 사람들이 가장 많이 접하는 미디어가 아닐까 싶다. 인터넷 특징상 시간과 장소에 국한하지 않고 국경없는 영상들이 많은 시점에서 자동자막 서비스는 많이 정교하지는 않지만 큰 도움이 된다. 이 원리또한 영상의 음성을 인식한 후에 머신러닝을 통한 번역으로 제공되는 것이다. 인공지능은 이미 우리 삶에 근접해 있다.
#
# https://youtube.googleblog.com/2017/02/one-billion-captioned-videos.html
#
# 3.   **이미지**
#
# 구글 이미지 검색
#
# 어떤 이미지의 이름을 알고 싶거나 관련 이미지를 검색하고 싶은데 가지고 있는 자료가 이미지 밖에 없다면 한번쯤은 사용해봤을 기능이 아닌가 한다. reverse image search 라고 불리는 이 기능은 이미지의 데이터화를 통하여 비슷한 그림을 찾아내는 방식이기 때문에 트레이싱을 찾아내는 등에는 강력하지만 사람이 생각하는 방향과는 약간 다를수 있다. 일반적으로 많은 자원이 필요하고 지금으로선 수준이 많이 높지 않은 부분에 주목하여 향후 빠른 성장을 보일 분야가 아닌가 생각한다.
#
# 여담으로 인터넷 사이트들의 메크로등을 식별하는곳에 많은 부분에서 이미지를 사용하는것을 보면 아직 얼마나 이미지 부분에 대한 인공지능 분야가 약한지를 나타낸다고 생각한다.
#
# https://namu.wiki/w/%EC%9D%B4%EB%AF%B8%EC%A7%80%20%EA%B2%80%EC%83%89
#
#
# 4.   **자율주행**
#
# 테슬라 오토파일럿
#
# 얼마전 한국의 LG U+ 에서 자동주행 자동차의 계발에 관한 기사가 나왔을 정도로 현재 진행중인 분야이고 관심이 많고 시장또한 큰 분야이다.
#
# 테슬라는 이런 자율주행의 시장화에 선발주자로 뛰어든 회사이다. 실제로 자률주행이라는 말이 엄청나게 생각될수도 있지만 현재로서도 앞차와의 간격 속도유지 등을 기본으로 하는 저차원적인 부분에서만 실용화된 분야이다. 하지만 선발주자로서 이미 많은 주행데이터를 보유하고 있기 때문에 법적인 부분에서 문제가 해결된다면 2020년인 지금 곧 완전한 자율주행이 가능하다고 말하고 있다. 테슬라의 경우 자율주행의 모든 기능이 딥러닝으로 이루어져있기 때문에 기존에 기반 프로그램을 중심으로 사용하는 우버나 웨이모에 비하여 가장 인공지능 자율주행에 가까운 모델을 가진 회사로 보인다.
#
# https://namu.wiki/w/%ED%85%8C%EC%8A%AC%EB%9D%BC%20%EC%98%A4%ED%86%A0%ED%8C%8C%EC%9D%BC%EB%9F%BF?from=%ED%85%8C%EC%8A%AC%EB%9D%BC%20%EC%9E%90%EC%9C%A8%EC%A3%BC%ED%96%89
#
#
#
#
#
#
# 1주차 과제를 하면서 인공지능 분야가 지금 우리 세대와 같이 자라고 있는 분야라는걸 다시 체감하게 되었고 아직은 갈 길이 멀다는걸 다시 한번 느끼게 되었습니다.
